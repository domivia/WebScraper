# %% [markdown]
# ## Import bibliotek

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Pobranie z serwisu (https://www.ceneo.pl/) opinii o wybranym produkcie

# %% [markdown]
# Potencjalne produkty
#
# *   7690465
# *   187595793
# *   130492450
# *   102474186
# *   47293506
# *   39562616

# %%
headers = {
    "Cookie": sv3=1.0_44e9110a-1e16-11f1-9d3a-bb0886467c38; urdsc=2; userCeneo=ID=9ad7535b-8143-4cd1-af81-a59042d067ce; __RequestVerificationToken=W2yjrIaM_q7vL9UfEfbCnaOgH-MMDFHcj-In3ywTyJE_HO7dPac5jOsvU11lptj9dlYDKeHQenlhnDKz0jMGc5NWrwskLVet5ewNLxz9vUI1; ai_user=Ni0QX|2026-03-12T13:20:43.889Z; __utmf=6d7474c56456783256644b1c1c1198a6_rMz9zR%2BIrLj3N7yIZ6Qf1Q%3D%3D; appType=%7B%22Value%22%3A1%7D; cProdCompare_v2=; browserBlStatus=0; ga4_ga=GA1.2.44e9110a-1e16-11f1-9d3a-bb0886467c38; _gcl_au=1.1.1156005282.1773321650; consentcookie=...; FPID=FPID2.2.SsOwNUpvuFyi%2FcV9VnKUJhyj1KGIcSTM8rJ28DFheA4%3D; FPLC=TY4m5y5WH%2B6z2%2F8c0UQvUeXRtMHQaD72PWw9SYPU7DmTQ28RdXncJRGDTyoXY7jCFRXTUOU7iDCeBymOioStILD4klBMdAClTA%2FYUAORGqDH9os%3D; _tt_enable_cookie=1; _ttp=01KKH3E1B2071AES4F8KW274GS_.tt.1; _fbp=fb.1.1773321782938.99116327646563964; nps3=SessionStartTime=1773321768,SurveyId=67,ClosedOrCompleted=True; st2=_gd%3dwww.google.com%2csref%3dhttps%3a%2f%2fwww.google.com%2f%2c_t%3d63908922240%2cencode%3dtrue; __rtbh.lid=%7B%22eventType%22%3A%22lid%22%2C%22id%22%3A%22hbchIm3vYgISB1wxpWYM%22%2C%22expiryDate%22%3A%222027-03-12T13%3A24%3A05.479Z%22%7D; __rtbh.aid=%7B%22eventType%22%3A%22aid%22%2C%22id%22%3A%2244e9110a-1e16-11f1-9d3a-bb0886467c38%22%2C%22expiryDate%22%3A%222027-03-12T13%3A24%3A05.482Z%22%7D; __rtbh.uid=%7B%22eventType%22%3A%22uid%22%2C%22id%22%3A%22unknown%22%2C%22expiryDate%22%3A%222027-03-12T13%3A24%3A05.485Z%22%7D; ai_session=G8ByG|1773321645334|1773321846127.4; ttcsid_CNK74OBC77U1PP7E4UR0=1773321782629::fD1F3IMKEqov488ImFr9.1.1773321847656.1; ttcsid=1773321782630::JqpFfCcS8qQ1JuXqTIa0.1.1773321847657.0; ga4_ga_K2N2M0CBQ6=GS2.2.s1773321645$o1$g1$t1773321859$j47$l0$h553762545
    "user_agent": Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36
}

# %%
url = "https://www.ceneo.pl/47293506#tab=reviews"
response = requests.get(url)
print(response.status_code)

# %%
page_dom = BeautifulSoup(response.text, "html.parser")
print(page_dom)

# %%
opinions = page_dom.find_all("div", class_="js_product-review")
print(opinions)
